# %% [markdown]
# <a href="https://colab.research.google.com/github/teakrcmar/KPI-predictions/blob/main/prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/teakrcmar/KPI-predictions.git
# Out:
# Cloning into 'KPI-predictions'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 9.12 KiB | 9.12 MiB/s, done.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

# %%
df = pd.read_csv("KPI-predictions/Marketing.csv")

# %%
df.head()
# Out:
#    id      c_date    campaign_name    category  campaign_id  impressions  \
# 0   1  2021-02-01   facebook_tier1      social       349043       148263
# 1   2  2021-02-01   facebOOK_tier2      social       348934       220688
# 2   3  2021-02-01       google_hot      search     89459845        22850
# 3   4  2021-02-01      google_wide      search       127823       147038
# 4   5  2021-02-01  youtube_blogger  influencer        10934       225800
#
#    mark_spent  clicks  leads  orders  revenue
# 0     7307.37    1210     13       1   4981.0
# 1    16300.20    1640     48       3  14962.0
# 2     5221.60     457      9       1   7981.0
# 3     6037.00    1196     24       1   2114.0
# 4    29962.20    2258     49      10  84490.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             308 non-null    int64
#  1   c_date         308 non-null    object
#  2   campaign_name  308 non-null    object
#  3   category       308 non-null    object
#  4   campaign_id    308 non-null    int64
#  5   impressions    308 non-null    int64
#  6   mark_spent     308 non-null    float64
#  7   clicks         308 non-null    int64
#  8   leads          308 non-null    int64
#  9   orders         308 non-null    int64
#  10  revenue        308 non-null    float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 26.6+ KB

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# 0

# %%
# Get the total number of entries
total_entries = len(df)

# Calculate the indices for splitting
train_end = int(total_entries * 0.8)  # 80% for training
val_end = int(total_entries * 0.9)   # 10% for validation

# Split the dataset
train_set = df.iloc[:train_end]  # First 80%
val_set = df.iloc[train_end:val_end]  # Next 10%
test_set = df.iloc[val_end:]  # Last 10%

# Print the sizes of the splits
print(f"Training set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")
print(f"Test set size: {len(test_set)}")
# Out:
# Training set size: 246
# Validation set size: 31
# Test set size: 31

# %%
# Calculate ROI
df['ROI'] = ((df['revenue'] - df['mark_spent']) / df['mark_spent']) * 100

# Calculate CPA_leads
df['CPA_leads'] = df['mark_spent'] / df['leads']

# Calculate CTR
df['CTR'] = (df['clicks'] / df['impressions']) * 100

# Calculate Conversion Rate from Clicks to Leads
df['Conversion_Rate_Clicks_Leads'] = (df['leads'] / df['clicks']) * 100

df['c_date'] = pd.to_datetime(df['c_date'])
df.set_index('c_date', inplace=True)

# %%
#Efficiency and Cost Analysis

# Cost Per Click (CPC)
df['CPC'] = df['mark_spent'] / df['clicks']
# Cost Per Thousand Impressions (CPM)
df['CPM'] = (df['mark_spent'] / df['impressions']) * 1000
# Average Order Value (AOV)
df['AOV'] = df['revenue'] / df['orders']
# Revenue Per Click (RPC)
df['RPC'] = df['revenue'] / df['clicks']

# Encode 'campaign_name' using LabelEncoder
label_encoder = LabelEncoder()
df['campaign_name'] = label_encoder.fit_transform(df['campaign_name'])

# Select relevant features
features = ['campaign_name', 'impressions', 'mark_spent', 'clicks', 'leads', 'orders']
target = 'revenue'

# Scale the data (features and target)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[features + [target]])

# %%
def create_sequences(data, target_index, seq_length=10):
    """
    Create input-output pairs for time-series forecasting.
    - data: Scaled dataset (numpy array)
    - target_index: Index of the target variable in the data
    - seq_length: Number of time steps in each sequence
    """
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length, :-1])  # Features
        y.append(data[i+seq_length, target_index])  # Target
    return np.array(X), np.array(y)

seq_length = 10  # Example: Use the last 10 days to predict the next day's revenue
X, y = create_sequences(scaled_data, target_index=-1, seq_length=seq_length)

X_train, y_train = X[:train_end], y[:train_end]
X_val, y_val = X[train_end:val_end], y[train_end:val_end]
X_test, y_test = X[val_end:], y[val_end:]

# %%
# Define the GRU model
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(seq_length, X_train.shape[2])),
    GRU(32),
    Dense(1)  # Single output for revenue prediction
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Display the model architecture
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 10, 64)              │          13,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,265 (90.88 KB)
#  Trainable params: 23,265 (90.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=300,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034 - val_loss: 2.5866e-04
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036 - val_loss: 1.3814e-04
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034 - val_loss: 1.9000e-04
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 1.7709e-04
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034 - val_loss: 1.5254e-04
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026 - val_loss: 1.3927e-04
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - val_loss: 1.8992e-04
# Epoch 8/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0034 - val_loss: 1.7143e-04
# Epoch 9/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 2.1388e-04
# Epoch 10/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - val_loss: 6.9309e-04
# Epoch 11/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - val_loss: 2.9686e-04
# Epoch 12/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 1.7759e-04
# Epoch 13/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 2.6049e-04
# Epoch 14/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - val_loss: 5.9735e-04
# Epoch 15/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - val_loss: 7.0414e-04
# Epoch 16/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0024 - val_loss: 4.0790e-04
# Epoch 17/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - val_loss: 2.0749e-04
# Epoch 18/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 1.8138e-04
# Epoch 19/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026 - val_loss: 3.0432e-04
# Epoch 20/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 3.0947e-04
# Epoch 21/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - val_loss: 2.1975e-04
# Epoch 22/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - val_loss: 2.7740e-04
# Epoch 23/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - val_loss: 3.6654e-04
# Epoch 24/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 2.3122e-04
# Epoch 25/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - val_loss: 1.8418e-04
# Epoch 26/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - val_loss: 1.8938e-04
# Epoch 27/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 2.1879e-04
# Epoch 28/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - val_loss: 2.9056e-04
# Epoch 29/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - val_loss: 2.1571e-04
# Epoch 30/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 2.1513e-04
# Epoch 31/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 2.0553e-04
# Epoch 32/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022 - val_loss: 2.0501e-04
# Epoch 33/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 2.3327e-04
# Epoch 34/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 2.1423e-04
# Epoch 35/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 2.0659e-04
# Epoch 36/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - val_loss: 3.7364e-04
# Epoch 37/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 4.1799e-04
# Epoch 38/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021 - val_loss: 2.6901e-04
# Epoch 39/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0017 - val_loss: 2.7692e-04
# Epoch 40/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0025 - val_loss: 2.9164e-04
# Epoch 41/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - val_loss: 2.4246e-04
# Epoch 42/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0020 - val_loss: 2.5905e-04
# Epoch 43/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0018 - val_loss: 2.6403e-04
# Epoch 44/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0027 - val_loss: 2.1348e-04
# Epoch 45/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0017 - val_loss: 2.5634e-04
# Epoch 46/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0018 - val_loss: 2.5331e-04
# Epoch 47/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0020 - val_loss: 2.0891e-04
# Epoch 48/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0020 - val_loss: 2.6042e-04
# Epoch 49/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0016 - val_loss: 2.5622e-04
# Epoch 50/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 2.6750e-04
# Epoch 51/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 2.3289e-04
# Epoch 52/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 2.3653e-04
# Epoch 53/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 2.6824e-04
# Epoch 54/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 5.0701e-04
# Epoch 55/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - val_loss: 3.3191e-04
# Epoch 56/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - val_loss: 2.5222e-04
# Epoch 57/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020 - val_loss: 3.3785e-04
# Epoch 58/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018 - val_loss: 3.2754e-04
# Epoch 59/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 3.0563e-04
# Epoch 60/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022 - val_loss: 2.5675e-04
# Epoch 61/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019 - val_loss: 3.6286e-04
# Epoch 62/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 2.9400e-04
# Epoch 63/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 2.9803e-04
# Epoch 64/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 3.0814e-04
# Epoch 65/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 3.0440e-04
# Epoch 66/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 2.9778e-04
# Epoch 67/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 2.8537e-04
# Epoch 68/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 2.7175e-04
# Epoch 69/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.7693e-04
# Epoch 70/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 2.3836e-04
# Epoch 71/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020 - val_loss: 3.4277e-04
# Epoch 72/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 2.9958e-04
# Epoch 73/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 2.3055e-04
# Epoch 74/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 3.1171e-04
# Epoch 75/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 3.0650e-04
# Epoch 76/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - val_loss: 2.4575e-04
# Epoch 77/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 2.8255e-04
# Epoch 78/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 4.4650e-04
# Epoch 79/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - val_loss: 3.5395e-04
# Epoch 80/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0015 - val_loss: 2.7211e-04
# Epoch 81/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.0633e-04
# Epoch 82/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - val_loss: 2.3205e-04
# Epoch 83/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0014 - val_loss: 3.2834e-04
# Epoch 84/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0013 - val_loss: 3.1291e-04
# Epoch 85/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0017 - val_loss: 3.2959e-04
# Epoch 86/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0016 - val_loss: 5.4978e-04
# Epoch 87/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0017 - val_loss: 9.3047e-04
# Epoch 88/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0015 - val_loss: 4.1299e-04
# Epoch 89/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 2.6924e-04
# Epoch 90/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0014 - val_loss: 2.7573e-04
# Epoch 91/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0015 - val_loss: 5.2357e-04
# Epoch 92/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0023 - val_loss: 2.9454e-04
# Epoch 93/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0014 - val_loss: 3.1653e-04
# Epoch 94/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 2.2501e-04
# Epoch 95/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0013 - val_loss: 2.6350e-04
# Epoch 96/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0015 - val_loss: 2.3729e-04
# Epoch 97/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0012 - val_loss: 2.4974e-04
# Epoch 98/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0011 - val_loss: 2.4773e-04
# Epoch 99/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 6.1488e-04
# Epoch 100/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0012 - val_loss: 3.1844e-04
# Epoch 101/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 4.2111e-04
# Epoch 102/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 2.4180e-04
# Epoch 103/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012 - val_loss: 2.3387e-04
# Epoch 104/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 2.5286e-04
# Epoch 105/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 2.3122e-04
# Epoch 106/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.0938e-04
# Epoch 107/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 5.2497e-04
# Epoch 108/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0018 - val_loss: 1.7678e-04
# Epoch 109/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 3.4701e-04
# Epoch 110/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 2.1134e-04
# Epoch 111/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 2.7930e-04
# Epoch 112/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - val_loss: 2.1374e-04
# Epoch 113/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013 - val_loss: 1.6949e-04
# Epoch 114/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 2.2733e-04
# Epoch 115/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - val_loss: 2.0568e-04
# Epoch 116/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.4856e-04 - val_loss: 1.7894e-04
# Epoch 117/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 1.9309e-04
# Epoch 118/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 3.0233e-04
# Epoch 119/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.8866e-04
# Epoch 120/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6643e-04 - val_loss: 2.1718e-04
# Epoch 121/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0011 - val_loss: 3.3463e-04
# Epoch 122/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.8719e-04 - val_loss: 2.3624e-04
# Epoch 123/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0013 - val_loss: 2.9108e-04
# Epoch 124/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0013 - val_loss: 4.6994e-04
# Epoch 125/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012 - val_loss: 2.0785e-04
# Epoch 126/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 2.1310e-04
# Epoch 127/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0010 - val_loss: 2.8075e-04
# Epoch 128/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 9.8901e-04 - val_loss: 1.8143e-04
# Epoch 129/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.8945e-04
# Epoch 130/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0014 - val_loss: 4.9148e-04
# Epoch 131/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0014 - val_loss: 2.8350e-04
# Epoch 132/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.9939e-04 - val_loss: 7.0815e-04
# Epoch 133/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 1.7928e-04
# Epoch 134/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0013 - val_loss: 1.7123e-04
# Epoch 135/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0011 - val_loss: 1.9915e-04
# Epoch 136/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 2.2793e-04
# Epoch 137/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.8588e-04 - val_loss: 1.9911e-04
# Epoch 138/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0010 - val_loss: 2.0883e-04
# Epoch 139/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0011 - val_loss: 1.9925e-04
# Epoch 140/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0010 - val_loss: 1.5609e-04
# Epoch 141/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 2.1791e-04
# Epoch 142/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.9479e-04 - val_loss: 1.8335e-04
# Epoch 143/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.2342e-04 - val_loss: 1.8121e-04
# Epoch 144/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - val_loss: 2.0652e-04
# Epoch 145/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011 - val_loss: 1.4804e-04
# Epoch 146/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.9893e-04 - val_loss: 1.7710e-04
# Epoch 147/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5163e-04 - val_loss: 2.2346e-04
# Epoch 148/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.5992e-04 - val_loss: 1.6383e-04
# Epoch 149/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5446e-04 - val_loss: 1.5400e-04
# Epoch 150/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2345e-04 - val_loss: 3.1156e-04
# Epoch 151/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1800e-04 - val_loss: 1.6017e-04
# Epoch 152/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7291e-04 - val_loss: 1.4450e-04
# Epoch 153/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8518e-04 - val_loss: 2.7979e-04
# Epoch 154/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7677e-04 - val_loss: 1.4391e-04
# Epoch 155/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.5519e-04 - val_loss: 1.5111e-04
# Epoch 156/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 2.5689e-04
# Epoch 157/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9794e-04 - val_loss: 1.4772e-04
# Epoch 158/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8872e-04 - val_loss: 2.0689e-04
# Epoch 159/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6949e-04 - val_loss: 2.2261e-04
# Epoch 160/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0010 - val_loss: 2.2315e-04
# Epoch 161/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 3.3067e-04
# Epoch 162/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012 - val_loss: 1.6426e-04
# Epoch 163/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 164/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 165/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 8.8855e-04
# Epoch 166/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.5202e-04
# Epoch 167/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 1.5330e-04
# Epoch 168/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - val_loss: 2.9312e-04
# Epoch 169/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 4.1635e-04
# Epoch 170/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 5.3465e-04
# Epoch 171/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 3.7874e-04
# Epoch 172/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.5398e-04
# Epoch 173/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.6160e-04 - val_loss: 2.2275e-04
# Epoch 174/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.1575e-04 - val_loss: 1.8902e-04
# Epoch 175/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4322e-04 - val_loss: 2.9161e-04
# Epoch 176/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.7801e-04 - val_loss: 1.5571e-04
# Epoch 177/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0010 - val_loss: 1.9082e-04
# Epoch 178/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5311e-04 - val_loss: 1.4948e-04
# Epoch 179/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2178e-04 - val_loss: 1.3580e-04
# Epoch 180/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4442e-04 - val_loss: 1.7001e-04
# Epoch 181/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.7018e-04 - val_loss: 2.4907e-04
# Epoch 182/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.0295e-04 - val_loss: 1.5128e-04
# Epoch 183/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.6717e-04 - val_loss: 2.1177e-04
# Epoch 184/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.9050e-04 - val_loss: 1.5873e-04
# Epoch 185/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.8102e-04 - val_loss: 2.0285e-04
# Epoch 186/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.7760e-04 - val_loss: 1.3002e-04
# Epoch 187/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.1807e-04 - val_loss: 1.1960e-04
# Epoch 188/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 1.5163e-04
# Epoch 189/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.0060e-04 - val_loss: 4.5529e-04
# Epoch 190/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.7873e-04 - val_loss: 2.3103e-04
# Epoch 191/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.3919e-04 - val_loss: 4.1660e-04
# Epoch 192/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0011 - val_loss: 1.2374e-04
# Epoch 193/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6688e-04 - val_loss: 2.4397e-04
# Epoch 194/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8125e-04 - val_loss: 1.4179e-04
# Epoch 195/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0838e-04 - val_loss: 1.7321e-04
# Epoch 196/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.9732e-04 - val_loss: 2.3764e-04
# Epoch 197/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4625e-04 - val_loss: 1.6191e-04
# Epoch 198/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.7252e-04 - val_loss: 2.5429e-04
# Epoch 199/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7127e-04 - val_loss: 1.6105e-04
# Epoch 200/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.7993e-04 - val_loss: 1.2873e-04
# Epoch 201/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.0325e-04 - val_loss: 1.7986e-04
# Epoch 202/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6764e-04 - val_loss: 3.1457e-04
# Epoch 203/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0997e-04 - val_loss: 1.6697e-04
# Epoch 204/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9165e-04 - val_loss: 1.2238e-04
# Epoch 205/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.9660e-04 - val_loss: 1.2446e-04
# Epoch 206/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4985e-04 - val_loss: 1.3040e-04
# Epoch 207/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5612e-04 - val_loss: 1.5321e-04
# Epoch 208/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2109e-04 - val_loss: 1.7601e-04
# Epoch 209/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2426e-04 - val_loss: 2.8383e-04
# Epoch 210/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0240e-04 - val_loss: 1.2179e-04
# Epoch 211/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6140e-04 - val_loss: 1.2519e-04
# Epoch 212/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.8193e-04 - val_loss: 1.2339e-04
# Epoch 213/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7485e-04 - val_loss: 1.2079e-04
# Epoch 214/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0010 - val_loss: 1.2756e-04
# Epoch 215/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6041e-04 - val_loss: 1.2234e-04
# Epoch 216/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.4573e-04 - val_loss: 1.2517e-04
# Epoch 217/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.6417e-04 - val_loss: 1.4140e-04
# Epoch 218/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9727e-04 - val_loss: 2.2127e-04
# Epoch 219/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.8390e-04 - val_loss: 1.3032e-04
# Epoch 220/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.8256e-04 - val_loss: 2.3843e-04
# Epoch 221/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.0164e-04 - val_loss: 1.2203e-04
# Epoch 222/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7073e-04 - val_loss: 1.1908e-04
# Epoch 223/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8366e-04 - val_loss: 1.2184e-04
# Epoch 224/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.4188e-04 - val_loss: 1.3847e-04
# Epoch 225/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8768e-04 - val_loss: 1.2255e-04
# Epoch 226/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.3569e-04 - val_loss: 1.1601e-04
# Epoch 227/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.1498e-04 - val_loss: 1.2479e-04
# Epoch 228/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8438e-04 - val_loss: 3.6280e-04
# Epoch 229/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4051e-04 - val_loss: 1.4421e-04
# Epoch 230/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.1775e-04 - val_loss: 1.4714e-04
# Epoch 231/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9728e-04 - val_loss: 2.3292e-04
# Epoch 232/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7681e-04 - val_loss: 1.6039e-04
# Epoch 233/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.6287e-04 - val_loss: 1.4470e-04
# Epoch 234/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4760e-04 - val_loss: 9.9351e-05
# Epoch 235/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.2751e-04 - val_loss: 4.3673e-04
# Epoch 236/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.3712e-04 - val_loss: 2.4149e-04
# Epoch 237/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.7755e-04 - val_loss: 1.4254e-04
# Epoch 238/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.2664e-04 - val_loss: 1.2962e-04
# Epoch 239/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.6215e-04 - val_loss: 2.0429e-04
# Epoch 240/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.4517e-04 - val_loss: 1.5991e-04
# Epoch 241/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.9982e-04 - val_loss: 1.2178e-04
# Epoch 242/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.9135e-04 - val_loss: 1.3442e-04
# Epoch 243/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.1582e-04 - val_loss: 1.2427e-04
# Epoch 244/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.3386e-04 - val_loss: 1.2495e-04
# Epoch 245/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.0320e-04 - val_loss: 1.7321e-04
# Epoch 246/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.5129e-04 - val_loss: 1.1982e-04
# Epoch 247/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.9359e-04 - val_loss: 1.1315e-04
# Epoch 248/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5400e-04 - val_loss: 1.3748e-04
# Epoch 249/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4162e-04 - val_loss: 1.1736e-04
# Epoch 250/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.5258e-04 - val_loss: 1.5633e-04
# Epoch 251/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.2982e-04 - val_loss: 1.5662e-04
# Epoch 252/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.9264e-04 - val_loss: 1.4302e-04
# Epoch 253/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.2287e-04 - val_loss: 2.5074e-04
# Epoch 254/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.8446e-04 - val_loss: 1.0845e-04
# Epoch 255/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6906e-04 - val_loss: 1.5386e-04
# Epoch 256/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2310e-04 - val_loss: 4.4252e-04
# Epoch 257/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8193e-04 - val_loss: 1.0429e-04
# Epoch 258/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0338e-04 - val_loss: 2.1005e-04
# Epoch 259/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.0458e-04 - val_loss: 1.6057e-04
# Epoch 260/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.7236e-04 - val_loss: 1.2179e-04
# Epoch 261/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.7283e-04 - val_loss: 1.7827e-04
# Epoch 262/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.2158e-04 - val_loss: 3.3546e-04
# Epoch 263/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 4.8237e-04
# Epoch 264/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.9051e-04 - val_loss: 1.4310e-04
# Epoch 265/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1625e-04 - val_loss: 2.5918e-04
# Epoch 266/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.0338e-04 - val_loss: 3.9675e-04
# Epoch 267/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7821e-04 - val_loss: 3.5196e-04
# Epoch 268/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.6583e-04 - val_loss: 1.5019e-04
# Epoch 269/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.4579e-04 - val_loss: 1.3961e-04
# Epoch 270/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5777e-04 - val_loss: 1.4196e-04
# Epoch 271/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8900e-04 - val_loss: 1.7551e-04
# Epoch 272/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0453e-04 - val_loss: 1.3423e-04
# Epoch 273/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.2389e-04 - val_loss: 1.4487e-04
# Epoch 274/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6810e-04 - val_loss: 1.3633e-04
# Epoch 275/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.3737e-04 - val_loss: 1.2079e-04
# Epoch 276/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0848e-04 - val_loss: 2.0033e-04
# Epoch 277/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4707e-04 - val_loss: 2.3214e-04
# Epoch 278/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7548e-04 - val_loss: 2.2566e-04
# Epoch 279/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4485e-04 - val_loss: 1.9342e-04
# Epoch 280/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.8294e-04 - val_loss: 2.3504e-04
# Epoch 281/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.1153e-04 - val_loss: 1.4117e-04
# Epoch 282/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.0891e-04 - val_loss: 2.9690e-04
# Epoch 283/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4286e-04 - val_loss: 2.0184e-04
# Epoch 284/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3136e-04 - val_loss: 1.6340e-04
# Epoch 285/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.9864e-04 - val_loss: 1.3686e-04
# Epoch 286/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.1655e-04 - val_loss: 1.3052e-04
# Epoch 287/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4613e-04 - val_loss: 2.0894e-04
# Epoch 288/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9101e-04 - val_loss: 1.1998e-04
# Epoch 289/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4316e-04 - val_loss: 1.6006e-04
# Epoch 290/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.5354e-04 - val_loss: 1.4553e-04
# Epoch 291/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.7106e-04 - val_loss: 1.4643e-04
# Epoch 292/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.7596e-04 - val_loss: 1.6178e-04
# Epoch 293/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.6475e-04 - val_loss: 1.6429e-04
# Epoch 294/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.3183e-04 - val_loss: 1.5728e-04
# Epoch 295/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.1247e-04 - val_loss: 1.6403e-04
# Epoch 296/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.4434e-04 - val_loss: 1.3517e-04
# Epoch 297/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5857e-04 - val_loss: 1.5677e-04
# Epoch 298/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.4009e-04 - val_loss: 1.8546e-04
# Epoch 299/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5643e-04 - val_loss: 1.2707e-04
# Epoch 300/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.0861e-04 - val_loss: 1.2739e-04

# %%
# Save the trained model
model.save("gru_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1449e-04
# Test Loss: 0.00011449104204075411

# %%
# Print a summary of the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 10, 64)              │          13,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 69,797 (272.65 KB)
#  Trainable params: 23,265 (90.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 46,532 (181.77 KB)

# %%
# Evaluate the model on the training data
train_loss = model.evaluate(X_train, y_train, verbose=1)
print(f"Training Loss: {train_loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5172e-04
# Training Loss: 0.0006184969679452479

# %%
# Add a placeholder column (zeros) to match the scaler's input shape
padding = np.zeros((y_train_pred.shape[0], 1))  # Placeholder for one missing column

# Combine features and predictions
y_train_pred_combined = np.hstack((X_train[:, -1, :-1], y_train_pred, padding))

# Reverse scale the predictions
y_train_pred_rescaled = scaler.inverse_transform(y_train_pred_combined)[:, -2]  # Extract the 'revenue' column
# Combine features and actual revenue
y_train_actual_combined = np.hstack((X_train[:, -1, :-1], y_train.reshape(-1, 1), padding))

# Reverse scale the actual revenue
y_train_actual_rescaled = scaler.inverse_transform(y_train_actual_combined)[:, -2]

# %%
# Display comparison
for i in range(10):  # First 10 samples
    print(f"Predicted Revenue: {y_train_pred_rescaled[i]:.2f}, Actual Revenue: {y_train_actual_rescaled[i]:.2f}")
# Out:
# Predicted Revenue: -0.48, Actual Revenue: 0.00
# Predicted Revenue: 0.78, Actual Revenue: 2.34
# Predicted Revenue: -0.71, Actual Revenue: 0.00
# Predicted Revenue: 2.25, Actual Revenue: 3.14
# Predicted Revenue: 7.12, Actual Revenue: 1.65
# Predicted Revenue: 11.38, Actual Revenue: 19.57
# Predicted Revenue: 6.74, Actual Revenue: 5.98
# Predicted Revenue: 0.13, Actual Revenue: 0.00
# Predicted Revenue: -2.32, Actual Revenue: 0.00
# Predicted Revenue: 0.91, Actual Revenue: 0.15
